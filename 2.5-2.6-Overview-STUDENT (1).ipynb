# %% [markdown]
# # Modeling Life Expectancy in the World

# %%
# run this to set up R
suppressMessages(library(coursekata))

# This code will load the R packages we will use

# set styles
css <- suppressWarnings(readLines("https://raw.githubusercontent.com/jimstigler/jupyter/master/ck_jupyter_styles_v2.css"))
IRdisplay::display_html(sprintf('<style>%s</style>', paste(css, collapse = "\n")))

# run this to pull in the data
AllWorld <- read.csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vQhIVfGa0h3qqdi-RlEBtpLhREoURgo0tK_efokXYEJJHe9KjLl-R2oXYKTbjXrWd2exwv1NWHPD2Uk/pub?gid=1108300079&single=true&output=csv")
World <- select(AllWorld, Country, Region, Code, LifeExpectancy, GirlsH1900, GirlsH1980, Happiness, GDPperCapita, FertRate, PeopleVacc, PeopleVacc_per100, Population2010, Population2020, WineServ) %>%
  na.omit()
# Out:
# <style><style>
# /* Force CSS block parsing */
# .teacher-note::before {
#     content: "";
#     display: none;
# }
#
# /* Teacher Notes */
# .teacher-note {
#     border: 3px dashed #fd7f91;
#     font-size: 14px;
#     color: #000000;
#     background-color: #ffe8ec;
#     padding: 10px;
#     border-radius: 5px;
#     line-height: 1.5;
# }
# .teacher-note ol, .teacher-note ul, .teacher-note li {
#     margin-top: 5px;
#     padding-left: 20px;
#     color: #000000;
# }
# .teacher-note code {
#     color: #000000;
#     background-color: #ffd3da;
# }
#
# /* Discussion Question */
# .discussion-question {
#     border: 3px solid #a88bd4;
#     font-size: 14px;
#     color: #000000;
#     background-color: #eee8f6;
#     padding: 10px;
#     border-radius: 5px;
#     line-height: 1.5;
# }
# .discussion-question h3 {
#     margin: 0; /* Remove top and bottom margin */
#     padding: 0; /* Ensure no padding is applied */
# }
# .discussion-question h3:first-child {
# ...

# %%
source("https://raw.githubusercontent.com/coursekata/teaching-apps/refs/heads/main/notebook-survey.R")
# Out:
# <div style="max-width:760px; margin:0 auto; font-family:-apple-system,BlinkMacSystemFont,'Segoe UI',sans-serif; width:100%; box-sizing:border-box; padding:12px 18px 14px; background:#ffffff; border:0.5px solid #e0e0e0; border-radius:6px;">
#
#   <div style="font-size:12px; color:#888888; margin-bottom:10px; font-style:italic;">Please sign in...</div>
#
#   <div style="display:grid; grid-template-columns:0.8fr 1.2fr; gap:8px 12px; width:100%; box-sizing:border-box;">
#
#     <div style="display:flex; align-items:center; gap:6px; min-width:0;">
#       <label style="font-size:12px; color:#666666; white-space:nowrap; flex-shrink:0;">Name</label>
#       <input id="name" type="text" autocomplete="off" tabindex="1" style="flex:1; min-width:0; height:28px; padding:0 7px; border:0.5px solid #cccccc; border-radius:4px; font-size:12px; background:#ffffff; color:#202124; box-sizing:border-box;" />
#     </div>
#
#     <div style="display:flex; align-items:center; gap:6px; min-width:0;">
# ...

# %% [markdown]
# <div class="discussion-question">
#
# The average life expectancy of countries varies widely in the world.
#
# **Discussion:** Find a few countries that have very high life expectancy. What is similar about those countries?
#
# <img src="https://i.postimg.cc/LmwGKzMx/image.png" alt="map of world colored by life expectancy">

# %% [markdown]
# ## About `World`
#
# We'll be looking at a data set called `World`, with data on countries from the Happy Planet Index project, updated with some historical height data (from [Our World in Data](https://ourworldindata.org/human-height)), drinking data (collected by the World Health Organization featured in [fivethirtyeight](https://fivethirtyeight.com/features/dear-mona-followup-where-do-people-drink-the-most-beer-wine-and-spirits/)), population and land characteristics, and vaccination data (from March 2023).
#
# It has 130 countries and the following variables:
#
# - `Country` Name of country
# - `Region` One of 5 UN defined regions: Africa, Americas, Asia, Europe, Oceania
# - `Code` Three-letter country codes defined by the International Organization for Standardization [(ISO)](https://www.iso.org/iso-3166-country-codes.html) to represent countries in a way that avoids errors since a country’s name changes depending on the language being used.
# - `LifeExpectancy` Average life expectancy (in years)
# - `GirlsH1900` The average of 18-year-old girls heights in 1900 (in cm)
# - `GirlsH1980`  The average of 18-year-old girls heights in 1980 (in cm)
# - `Happiness` Score on a 0-10 scale for average level of happiness (10 being happiest)
# - `GDPperCapita` Gross Domestic Product (per capita)
# - `FertRate` The average number of children that will be born to a woman over her lifetime
# - `PeopleVacc` total number of people vaccinated in the country
# - `PeopleVacc_per100` ratio (in percent) between the total number of people vaccinated and total population in the country
# - `Population2010` Population (in millions) in 2010
# - `Population2020` Population (in millions) in 2020
# - `WineServ` Average wine consumption per capita for those age 15 and over per week (collected by WHO)

# %% [markdown]
# ## 1.0: Explore the Data

# %% [markdown]
# ### 1.1 Take look at the data frame `World`. What are some variables that may be important for predicting life expectancy in the world?

# %%
# write some code
#head(World)
#glimpse(World)
#sample(World, 5)

# %% [markdown]
# ### Use your data wrangling codes (like `arrange()` or `filter()`) to look for patterns.

# %%
# write some code here

# %% [markdown]
# ### What are some variables that may be important for predicting life expectancy in the world?
# - Why do you think they will be good predictors?
# - What do you expect to see in graphs?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 1.2 Write a few word equations expressing how a predictor variable could help us predict variation in life expectancy. Make some scatter plots to explore those word equations.

# %% [markdown]
# *type your word equations here*

# %%
# write code to create scatter plots

# %% [markdown]
# ## 2.0: Exploring the Girls' Height Hypothesis and Y-Intercept

# %% [markdown]
# ### 2.1 Write a word equation to explore this idea. Then create a scatterplot.

# %% [markdown]
# *type your response here*

# %%
# write some code

# %% [markdown]
# ### 2.2 Try to find the equation of a line that would predict a country's life expectancy based on girls height.

# %% [markdown]
# <div class="guided-notes">
#
# **Paper Activity:** Just eyeballing the line is extremely hard in this case. Use the graph and the straw to find a decent line of predictions for this data.
#
# </div>

# %% [markdown]
# <div class="guided-notes">
#
# ### 2.3 Write the definition of a y-intercept in your notes.
# What does the y-intercept ($b_0$) mean in the context of our hypothesis?
#
# </div>

# %% [markdown]
# ### 2.4 🤔 Something seems tricky about trying to find the y-intercept of this graph.
# - Does the graph actually show what happens when GirlsHeight = 0?
# - Would it be easy or hard to estimate where the line crosses the y-axis?
# - Why might this be a problem if you’re trying to model the relationship?

# %% [markdown]
# *type your reponse here*

# %% [markdown]
# <div class="guided-notes">
#
# ### 2.5 Revisit Your Equation
# Using the *new* paper graph, create a linear model. Then estimate the slope and y-intercept.

# %% [markdown]
# ### 2.6 Use your paper-based estimation of the line to fit a line to this data using `gf_abline`.
# Edit the code below.

# %%
# edit this code
gf_point(LifeExpectancy ~ GirlsH1980, data = World, shape = 1)
# Out:
# plot without title

# %% [markdown]
# ### 2.7 Write a custom function for your line. What would your function predict to be a country's life expectancy for an average girls' height of 0?

# %%
# write some code

# %% [markdown]
# ### 2.8 Place your function on the scatterplot as well as the prediction for `GirlsH1980 = 0`.

# %%
gf_point(LifeExpectancy ~ GirlsH1980, data = World, shape = 1) %>%
  gf_function(my_function, color = "green4") %>%
  gf_point(my_function(0) ~ 0, color = "green4")
# Out:
# Error: object 'my_function' not found
# Traceback:
#
# 1. gf_point(., my_function(0) ~ 0, color = "green4")
# 2. gf_function(., my_function, color = "green4")
# 3. do.call(ggplot2::layer, list(geom = "path", stat = "function",
#  .     position = "identity", mapping = afq$mapping, inherit.aes = inherit,
#  .     data = data, params = c(list(fun = fun), lapply(afq$qdots,
#  .         rlang::f_rhs))))
# 4. .handleSimpleError(function (cnd)
#  . {
#  .     watcher$capture_plot_and_output()
#  .     cnd <- sanitize_call(cnd)
#  .     watcher$push(cnd)
#  .     switch(on_error, continue = invokeRestart("eval_continue"),
#  .         stop = invokeRestart("eval_stop"), error = NULL)
#  . }, "object 'my_function' not found", base::quote(NULL))

# %% [markdown]
# <div class="discussion-question">
#
# ### 2.9 Discussion Question: Why aren't there any data points near the prediction for when `GirlsH1980 = 0`?

# %% [markdown]
# ## 3.0: Exploring the Fertility Rate Hypothesis

# %% [markdown]
# <div class="discussion-question">
#
# ### 3.1 Discussion Question:Do you think countries with higher fertility rate (more babies per mother) would have longer or shorter life expectancies? Do you think there is a relationship at all?

# %% [markdown]
# *type your reponse here*

# %% [markdown]
# ### 3.2 Write a word equation to explore this idea. Then create a scatterplot.

# %% [markdown]
# *type your response here*

# %%
# write some code

# %% [markdown]
# ### 3.3 What does the variable `FertRate` mean? How should we interpret those numbers on the x-axis?

# %% [markdown]
# *type your reposnse here*

# %% [markdown]
# ### 3.4 What pattern does the graph show?

# %% [markdown]
# *type your reposnse here*

# %% [markdown]
# ### 3.5 Make two predictions: $f(0)$ and $f(6)$.
# Graph your predictions below.

# %%
#edit the code below to add your predictions 
gf_point(LifeExpectancy ~ FertRate, data = World, shape = 1) %>%
    gf_point(Y~X, color = red) %>%
    gf_point(Y~X, color = red)

# %% [markdown]
# ### Intepret your predictions for $f(0)$ and $f(6)$.
# What do they mean in the context of the data?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 3.6 Use your predictions to calculate the slope.

# %%
# make your calculations here

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 3.7 Graph your prediction line:
# Use your slope and your prediction at FertRate = 0 to draw the line.

# %%
#edit this code to add your linear model 

gf_point(LifeExpectancy ~ FertRate, data = World, shape = 1)

# %% [markdown]
# ### 3.8 What does your slope tell you?
# How much does Life Expectancy change for each additional baby per mother?

# %% [markdown]
# *type your response here*

# %% [markdown]
# ## 4.0: Your Own Hypothesis
#
# Explore the data set to come up with your own hypothesis about life expectancy.
#
# 1. Write your hypothesis with regular words as well as a word equation.
# 2. Make a graph of your hypothesis.
# 3. Make a linear model of your hypothesis. Put it on your graph and write it as an equation.
# 4. Sometimes a linear model isn't a great model. Is your hypothesis described well with a linear equation? Why or why not?

# %% [markdown]
# ### 4.1 Write your hypothesis with regular words as well as a word equation.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 4.2 Make a graph of your hypothesis.

# %%
# write some code here

# %% [markdown]
# ### 4.3 Make a linear model of your hypothesis. Put it on your graph and write it as an equation.

# %% [markdown]
# ### 4.4 Explain what your $b_0$ and $b_1$ mean in context of your hypothesis.

# %% [markdown]
# *type your response here*

# %% [markdown]
# ### 4.5 Sometimes a linear model isn't a great model. Is your hypothesis described well with a linear equation? Why or why not?

# %% [markdown]
# *type your response here*

# %%
#write some code

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=69160fbc-ed07-4747-a631-40af8243d52c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
